# %% [markdown]
# # Artificial Intelligence Nanodegree
#
# ## Convolutional Neural Networks
#
# ---
#
# In this notebook, we train a CNN to classify images from the CIFAR-10 database.
#
# ### 1. Load CIFAR-10 Database

# %%
import keras
import tensorflow as tf
from keras.datasets import cifar10
from keras import backend as K
config = tf.ConfigProto()
config.gpu_options.allow_growth=True
sess = tf.Session(config=config)
K.set_session(sess)

# load the pre-shuffled train and test data
(x_train, y_train), (x_test, y_test) = cifar10.load_data()
# Out:
# Using TensorFlow backend.

# %% [markdown]
# ### 2. Visualize the First 24 Training Images

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

fig = plt.figure(figsize=(20,5))
for i in range(36):
    ax = fig.add_subplot(3, 12, i + 1, xticks=[], yticks=[])
    ax.imshow(np.squeeze(x_train[i]))

# %% [markdown]
# ### 3. Rescale the Images by Dividing Every Pixel in Every Image by 255

# %%
# rescale [0,255] --> [0,1]
x_train = x_train.astype('float32')/255
x_test = x_test.astype('float32')/255

# %% [markdown]
# ### 4.  Break Dataset into Training, Testing, and Validation Sets

# %%
from keras.utils import np_utils

# one-hot encode the labels
num_classes = len(np.unique(y_train))
y_train = keras.utils.to_categorical(y_train, num_classes)
y_test = keras.utils.to_categorical(y_test, num_classes)

# break training set into training and validation sets
(x_train, x_valid) = x_train[5000:], x_train[:5000]
(y_train, y_valid) = y_train[5000:], y_train[:5000]

# print shape of training set
print('x_train shape:', x_train.shape)

# print number of training, validation, and test images
print(x_train.shape[0], 'train samples')
print(x_test.shape[0], 'test samples')
print(x_valid.shape[0], 'validation samples')
# Out:
# x_train shape: (45000, 32, 32, 3)
# 45000 train samples
# 10000 test samples
# 5000 validation samples

# %% [markdown]
# ### 5. Define the Model Architecture

# %%
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout

model = Sequential()
model.add(Conv2D(filters=32, kernel_size=2, padding='same', activation='relu', 
                        input_shape=(32, 32, 3)))
model.add(MaxPooling2D(pool_size=2))
model.add(Dropout(0.3))
model.add(Conv2D(filters=64, kernel_size=2, padding='same', activation='relu'))
model.add(MaxPooling2D(pool_size=2))
model.add(Dropout(0.3))
model.add(Conv2D(filters=128, kernel_size=2, padding='same', activation='relu'))
model.add(MaxPooling2D(pool_size=2))
model.add(Dropout(0.3))
model.add(Conv2D(filters=256, kernel_size=2, padding='same', activation='relu'))
model.add(MaxPooling2D(pool_size=2))
model.add(Dropout(0.3))
model.add(Conv2D(filters=512, kernel_size=2, padding='same', activation='relu'))
model.add(MaxPooling2D(pool_size=2))
model.add(Dropout(0.3))
model.add(Flatten())
model.add(Dense(256, activation='relu'))
model.add(Dropout(0.4))
model.add(Dense(10, activation='softmax'))

model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_16 (Conv2D)           (None, 32, 32, 32)        416
# _________________________________________________________________
# max_pooling2d_16 (MaxPooling (None, 16, 16, 32)        0
# _________________________________________________________________
# dropout_20 (Dropout)         (None, 16, 16, 32)        0
# _________________________________________________________________
# conv2d_17 (Conv2D)           (None, 16, 16, 64)        8256
# _________________________________________________________________
# max_pooling2d_17 (MaxPooling (None, 8, 8, 64)          0
# _________________________________________________________________
# dropout_21 (Dropout)         (None, 8, 8, 64)          0
# _________________________________________________________________
# conv2d_18 (Conv2D)           (None, 8, 8, 128)         32896
# _________________________________________________________________
# max_pooling2d_18 (MaxPooling (None, 4, 4, 128)         0
# _________________________________________________________________
# dropout_22 (Dropout)         (None, 4, 4, 128)         0
# _________________________________________________________________
# conv2d_19 (Conv2D)           (None, 4, 4, 256)         131328
# _________________________________________________________________
# max_pooling2d_19 (MaxPooling (None, 2, 2, 256)         0
# _________________________________________________________________
# dropout_23 (Dropout)         (None, 2, 2, 256)         0
# _________________________________________________________________
# conv2d_20 (Conv2D)           (None, 2, 2, 512)         524800
# _________________________________________________________________
# max_pooling2d_20 (MaxPooling (None, 1, 1, 512)         0
# _________________________________________________________________
# dropout_24 (Dropout)         (None, 1, 1, 512)         0
# _________________________________________________________________
# flatten_4 (Flatten)          (None, 512)               0
# _________________________________________________________________
# dense_7 (Dense)              (None, 256)               131328
# _________________________________________________________________
# dropout_25 (Dropout)         (None, 256)               0
# _________________________________________________________________
# dense_8 (Dense)              (None, 10)                2570
# =================================================================
# Total params: 831,594
# Trainable params: 831,594
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### 6. Compile the Model

# %%
# compile the model
model.compile(loss='categorical_crossentropy', optimizer='rmsprop', 
                  metrics=['accuracy'])

# %% [markdown]
# ### 7. Train the Model

# %%
from keras.callbacks import ModelCheckpoint   

# train the model
checkpointer = ModelCheckpoint(filepath='model-cnn.weights.best.hdf5', verbose=1, 
                               save_best_only=True)
hist = model.fit(x_train, y_train, batch_size=32, epochs=100,
          validation_data=(x_valid, y_valid), callbacks=[checkpointer], 
          verbose=2, shuffle=True)
# Out:
# Train on 45000 samples, validate on 5000 samples
# Epoch 1/100
# Epoch 00000: val_loss improved from inf to 1.63560, saving model to model-cnn.weights.best.hdf5
# 19s - loss: 1.8632 - acc: 0.3055 - val_loss: 1.6356 - val_acc: 0.3916
# Epoch 2/100
# Epoch 00001: val_loss improved from 1.63560 to 1.43551, saving model to model-cnn.weights.best.hdf5
# 18s - loss: 1.5700 - acc: 0.4310 - val_loss: 1.4355 - val_acc: 0.4808
# Epoch 3/100
# Epoch 00002: val_loss did not improve
# 18s - loss: 1.4771 - acc: 0.4710 - val_loss: 1.4590 - val_acc: 0.4624
# Epoch 4/100
# Epoch 00003: val_loss improved from 1.43551 to 1.42144, saving model to model-cnn.weights.best.hdf5
# 18s - loss: 1.4364 - acc: 0.4895 - val_loss: 1.4214 - val_acc: 0.5076
# Epoch 5/100
# Epoch 00004: val_loss did not improve
# 18s - loss: 1.4339 - acc: 0.4953 - val_loss: 1.6422 - val_acc: 0.4144
# Epoch 6/100
# Epoch 00005: val_loss improved from 1.42144 to 1.32750, saving model to model-cnn.weights.best.hdf5
# 18s - loss: 1.4264 - acc: 0.4963 - val_loss: 1.3275 - val_acc: 0.5396
# Epoch 7/100
# Epoch 00006: val_loss improved from 1.32750 to 1.25800, saving model to model-cnn.weights.best.hdf5
# 18s - loss: 1.4423 - acc: 0.4963 - val_loss: 1.2580 - val_acc: 0.5582
# Epoch 8/100
# Epoch 00007: val_loss did not improve
# 18s - loss: 1.4509 - acc: 0.4894 - val_loss: 1.5889 - val_acc: 0.4452
# Epoch 9/100
# Epoch 00008: val_loss did not improve
# 18s - loss: 1.4685 - acc: 0.4837 - val_loss: 1.9003 - val_acc: 0.3658
# Epoch 10/100
# Epoch 00009: val_loss did not improve
# 18s - loss: 1.4948 - acc: 0.4817 - val_loss: 1.5253 - val_acc: 0.4510
# Epoch 11/100
# Epoch 00010: val_loss did not improve
# 18s - loss: 1.5030 - acc: 0.4753 - val_loss: 1.3243 - val_acc: 0.5418
# Epoch 12/100
# Epoch 00011: val_loss did not improve
# 18s - loss: 1.5202 - acc: 0.4723 - val_loss: 1.4091 - val_acc: 0.4772
# Epoch 13/100
# Epoch 00012: val_loss did not improve
# 18s - loss: 1.5354 - acc: 0.4653 - val_loss: 1.4421 - val_acc: 0.4846
# Epoch 14/100
# Epoch 00013: val_loss did not improve
# 18s - loss: 1.5396 - acc: 0.4658 - val_loss: 1.5060 - val_acc: 0.4638
# Epoch 15/100
# Epoch 00014: val_loss did not improve
# 18s - loss: 1.5631 - acc: 0.4555 - val_loss: 1.5948 - val_acc: 0.3830
# Epoch 16/100
# Epoch 00015: val_loss did not improve
# 18s - loss: 1.5721 - acc: 0.4551 - val_loss: 1.6379 - val_acc: 0.4142
# Epoch 17/100
# Epoch 00016: val_loss did not improve
# 18s - loss: 1.5881 - acc: 0.4472 - val_loss: 1.4532 - val_acc: 0.4784
# Epoch 18/100
# Epoch 00017: val_loss did not improve
# 18s - loss: 1.6071 - acc: 0.4418 - val_loss: 1.6658 - val_acc: 0.3972
# Epoch 19/100
# Epoch 00018: val_loss did not improve
# 18s - loss: 1.6078 - acc: 0.4450 - val_loss: 1.9594 - val_acc: 0.2656
# Epoch 20/100
# Epoch 00019: val_loss did not improve
# 18s - loss: 1.6188 - acc: 0.4388 - val_loss: 1.6219 - val_acc: 0.3970
# Epoch 21/100
# Epoch 00020: val_loss did not improve
# 18s - loss: 1.6136 - acc: 0.4378 - val_loss: 2.1119 - val_acc: 0.2642
# Epoch 22/100
# Epoch 00021: val_loss did not improve
# 18s - loss: 1.6411 - acc: 0.4314 - val_loss: 1.6446 - val_acc: 0.3658
# Epoch 23/100
# Epoch 00022: val_loss did not improve
# 18s - loss: 1.6320 - acc: 0.4306 - val_loss: 1.4595 - val_acc: 0.4416
# Epoch 24/100
# Epoch 00023: val_loss did not improve
# 18s - loss: 1.6593 - acc: 0.4269 - val_loss: 1.7328 - val_acc: 0.3914
# Epoch 25/100
# Epoch 00024: val_loss did not improve
# 18s - loss: 1.6541 - acc: 0.4223 - val_loss: 2.5298 - val_acc: 0.1558
# Epoch 26/100
# Epoch 00025: val_loss did not improve
# 18s - loss: 1.6545 - acc: 0.4227 - val_loss: 1.8631 - val_acc: 0.3258
# Epoch 27/100
# Epoch 00026: val_loss did not improve
# 18s - loss: 1.6671 - acc: 0.4165 - val_loss: 2.0026 - val_acc: 0.2608
# Epoch 28/100
# Epoch 00027: val_loss did not improve
# 17s - loss: 1.6793 - acc: 0.4172 - val_loss: 1.6852 - val_acc: 0.3942
# Epoch 29/100
# Epoch 00028: val_loss did not improve
# 18s - loss: 1.6841 - acc: 0.4109 - val_loss: 2.5627 - val_acc: 0.2384
# Epoch 30/100
# Epoch 00029: val_loss did not improve
# 18s - loss: 1.6821 - acc: 0.4121 - val_loss: 3.1660 - val_acc: 0.1514
# Epoch 31/100
# Epoch 00030: val_loss did not improve
# 18s - loss: 1.6911 - acc: 0.4098 - val_loss: 2.9547 - val_acc: 0.1730
# Epoch 32/100
# Epoch 00031: val_loss did not improve
# 18s - loss: 1.6898 - acc: 0.4038 - val_loss: 2.9881 - val_acc: 0.1412
# Epoch 33/100
# Epoch 00032: val_loss did not improve
# 18s - loss: 1.7023 - acc: 0.4016 - val_loss: 1.8819 - val_acc: 0.2796
# Epoch 34/100
# Epoch 00033: val_loss did not improve
# 18s - loss: 1.7077 - acc: 0.3991 - val_loss: 1.8722 - val_acc: 0.3140
# Epoch 35/100
# Epoch 00034: val_loss did not improve
# 18s - loss: 1.7152 - acc: 0.3954 - val_loss: 1.6303 - val_acc: 0.3812
# Epoch 36/100
# Epoch 00035: val_loss did not improve
# 17s - loss: 1.7230 - acc: 0.4005 - val_loss: 1.8873 - val_acc: 0.3316
# Epoch 37/100
# Epoch 00036: val_loss did not improve
# 18s - loss: 1.7232 - acc: 0.3925 - val_loss: 1.6672 - val_acc: 0.3614
# Epoch 38/100
# Epoch 00037: val_loss did not improve
# 17s - loss: 1.7105 - acc: 0.3960 - val_loss: 1.6801 - val_acc: 0.4058
# Epoch 39/100
# Epoch 00038: val_loss did not improve
# 18s - loss: 1.7360 - acc: 0.3862 - val_loss: 1.6969 - val_acc: 0.4014
# Epoch 40/100
# Epoch 00039: val_loss did not improve
# 17s - loss: 1.7202 - acc: 0.3923 - val_loss: 1.6628 - val_acc: 0.4160
# Epoch 41/100
# Epoch 00040: val_loss did not improve
# 17s - loss: 1.7262 - acc: 0.3904 - val_loss: 2.0803 - val_acc: 0.3116
# Epoch 42/100
# Epoch 00041: val_loss did not improve
# 17s - loss: 1.7207 - acc: 0.3931 - val_loss: 1.6487 - val_acc: 0.3872
# Epoch 43/100
# Epoch 00042: val_loss did not improve
# 17s - loss: 1.7306 - acc: 0.3887 - val_loss: 1.8078 - val_acc: 0.3414
# Epoch 44/100
# Epoch 00043: val_loss did not improve
# 17s - loss: 1.7476 - acc: 0.3816 - val_loss: 1.8463 - val_acc: 0.3388
# Epoch 45/100
# Epoch 00044: val_loss did not improve
# 17s - loss: 1.7298 - acc: 0.3887 - val_loss: 1.5255 - val_acc: 0.4678
# Epoch 46/100
# Epoch 00045: val_loss did not improve
# 17s - loss: 1.7542 - acc: 0.3812 - val_loss: 1.8401 - val_acc: 0.3044
# Epoch 47/100
# Epoch 00046: val_loss did not improve
# 17s - loss: 1.7331 - acc: 0.3803 - val_loss: 1.5981 - val_acc: 0.3966
# Epoch 48/100
# Epoch 00047: val_loss did not improve
# 17s - loss: 1.7479 - acc: 0.3835 - val_loss: 2.2846 - val_acc: 0.2058
# Epoch 49/100
# Epoch 00048: val_loss did not improve
# 17s - loss: 1.7700 - acc: 0.3752 - val_loss: 1.8265 - val_acc: 0.3130
# Epoch 50/100
# Epoch 00049: val_loss did not improve
# 17s - loss: 1.7777 - acc: 0.3712 - val_loss: 1.7312 - val_acc: 0.4110
# Epoch 51/100
# Epoch 00050: val_loss did not improve
# 17s - loss: 1.7811 - acc: 0.3711 - val_loss: 1.6717 - val_acc: 0.3974
# Epoch 52/100
# Epoch 00051: val_loss did not improve
# 17s - loss: 1.7644 - acc: 0.3732 - val_loss: 1.8143 - val_acc: 0.3688
# Epoch 53/100
# Epoch 00052: val_loss did not improve
# 17s - loss: 1.7835 - acc: 0.3689 - val_loss: 1.7143 - val_acc: 0.3992
# Epoch 54/100
# Epoch 00053: val_loss did not improve
# 17s - loss: 1.7814 - acc: 0.3697 - val_loss: 1.6767 - val_acc: 0.3716
# Epoch 55/100
# Epoch 00054: val_loss did not improve
# 17s - loss: 1.7772 - acc: 0.3677 - val_loss: 2.1223 - val_acc: 0.2146
# Epoch 56/100
# Epoch 00055: val_loss did not improve
# 17s - loss: 1.7636 - acc: 0.3702 - val_loss: 1.7596 - val_acc: 0.3684
# Epoch 57/100
# Epoch 00056: val_loss did not improve
# 17s - loss: 1.7837 - acc: 0.3639 - val_loss: 2.6009 - val_acc: 0.1786
# Epoch 58/100
# Epoch 00057: val_loss did not improve
# 17s - loss: 1.7884 - acc: 0.3700 - val_loss: 1.7074 - val_acc: 0.3964
# Epoch 59/100
# Epoch 00058: val_loss did not improve
# 17s - loss: 1.7875 - acc: 0.3641 - val_loss: 1.9809 - val_acc: 0.2996
# Epoch 60/100
# Epoch 00059: val_loss did not improve
# 17s - loss: 1.7890 - acc: 0.3665 - val_loss: 1.6898 - val_acc: 0.3970
# Epoch 61/100
# Epoch 00060: val_loss did not improve
# 17s - loss: 1.7735 - acc: 0.3635 - val_loss: 3.0294 - val_acc: 0.1556
# Epoch 62/100
# Epoch 00061: val_loss did not improve
# 17s - loss: 1.7869 - acc: 0.3643 - val_loss: 1.7661 - val_acc: 0.3846
# Epoch 63/100
# Epoch 00062: val_loss did not improve
# 18s - loss: 1.7907 - acc: 0.3574 - val_loss: 1.8074 - val_acc: 0.3322
# Epoch 64/100
# Epoch 00063: val_loss did not improve
# 17s - loss: 1.7768 - acc: 0.3623 - val_loss: 1.9185 - val_acc: 0.2966
# Epoch 65/100
# Epoch 00064: val_loss did not improve
# 17s - loss: 1.7816 - acc: 0.3619 - val_loss: 1.6343 - val_acc: 0.4248
# Epoch 66/100
# Epoch 00065: val_loss did not improve
# 17s - loss: 1.7886 - acc: 0.3584 - val_loss: 1.8596 - val_acc: 0.3572
# Epoch 67/100
# Epoch 00066: val_loss did not improve
# 24s - loss: 1.7985 - acc: 0.3560 - val_loss: 1.8100 - val_acc: 0.3260
# Epoch 68/100
# Epoch 00067: val_loss did not improve
# 30s - loss: 1.8167 - acc: 0.3536 - val_loss: 2.4517 - val_acc: 0.2020
# Epoch 69/100
# Epoch 00068: val_loss did not improve
# 30s - loss: 1.8027 - acc: 0.3536 - val_loss: 1.8634 - val_acc: 0.3540
# Epoch 70/100
# Epoch 00069: val_loss did not improve
# 30s - loss: 1.8127 - acc: 0.3509 - val_loss: 1.8719 - val_acc: 0.2944
# Epoch 71/100
# Epoch 00070: val_loss did not improve
# 30s - loss: 1.8046 - acc: 0.3548 - val_loss: 1.8632 - val_acc: 0.2836
# Epoch 72/100
# Epoch 00071: val_loss did not improve
# 30s - loss: 1.7918 - acc: 0.3560 - val_loss: 1.7878 - val_acc: 0.3444
# Epoch 73/100
# Epoch 00072: val_loss did not improve
# 30s - loss: 1.7914 - acc: 0.3623 - val_loss: 2.5489 - val_acc: 0.1690
# Epoch 74/100
# Epoch 00073: val_loss did not improve
# 30s - loss: 1.8071 - acc: 0.3522 - val_loss: 1.9894 - val_acc: 0.2658
# Epoch 75/100
# Epoch 00074: val_loss did not improve
# 30s - loss: 1.8056 - acc: 0.3518 - val_loss: 1.6584 - val_acc: 0.3858
# Epoch 76/100
# Epoch 00075: val_loss did not improve
# 30s - loss: 1.8011 - acc: 0.3543 - val_loss: 1.8923 - val_acc: 0.3072
# Epoch 77/100
# Epoch 00076: val_loss did not improve
# 30s - loss: 1.7998 - acc: 0.3540 - val_loss: 1.6787 - val_acc: 0.3700
# Epoch 78/100
# Epoch 00077: val_loss did not improve
# 30s - loss: 1.7906 - acc: 0.3536 - val_loss: 1.7990 - val_acc: 0.3542
# Epoch 79/100
# Epoch 00078: val_loss did not improve
# 30s - loss: 1.8102 - acc: 0.3518 - val_loss: 1.7172 - val_acc: 0.3828
# Epoch 80/100
# Epoch 00079: val_loss did not improve
# 30s - loss: 1.8017 - acc: 0.3521 - val_loss: 1.8603 - val_acc: 0.3174
# Epoch 81/100
# Epoch 00080: val_loss did not improve
# 30s - loss: 1.7923 - acc: 0.3524 - val_loss: 1.7853 - val_acc: 0.3232
# Epoch 82/100
# Epoch 00081: val_loss did not improve
# 30s - loss: 1.7921 - acc: 0.3512 - val_loss: 1.8581 - val_acc: 0.3084
# Epoch 83/100
# Epoch 00082: val_loss did not improve
# 30s - loss: 1.8002 - acc: 0.3522 - val_loss: 1.7043 - val_acc: 0.3766
# Epoch 84/100
# Epoch 00083: val_loss did not improve
# 30s - loss: 1.8274 - acc: 0.3467 - val_loss: 1.8637 - val_acc: 0.2914
# Epoch 85/100
# Epoch 00084: val_loss did not improve
# 30s - loss: 1.8078 - acc: 0.3498 - val_loss: 1.7532 - val_acc: 0.3490
# Epoch 86/100
# Epoch 00085: val_loss did not improve
# 30s - loss: 1.8085 - acc: 0.3490 - val_loss: 1.7743 - val_acc: 0.3184
# Epoch 87/100
# Epoch 00086: val_loss did not improve
# 30s - loss: 1.8102 - acc: 0.3500 - val_loss: 1.7586 - val_acc: 0.3566
# Epoch 88/100
# Epoch 00087: val_loss did not improve
# 30s - loss: 1.8111 - acc: 0.3480 - val_loss: 1.8571 - val_acc: 0.2890
# Epoch 89/100
# Epoch 00088: val_loss did not improve
# 30s - loss: 1.8090 - acc: 0.3483 - val_loss: 1.8008 - val_acc: 0.3258
# Epoch 90/100
# Epoch 00089: val_loss did not improve
# 30s - loss: 1.8165 - acc: 0.3491 - val_loss: 1.8422 - val_acc: 0.3402
# Epoch 91/100
# Epoch 00090: val_loss did not improve
# 30s - loss: 1.8241 - acc: 0.3465 - val_loss: 2.0994 - val_acc: 0.2214
# Epoch 92/100
# Epoch 00091: val_loss did not improve
# 30s - loss: 1.8226 - acc: 0.3465 - val_loss: 1.8653 - val_acc: 0.2930
# Epoch 93/100
# Epoch 00092: val_loss did not improve
# 30s - loss: 1.8322 - acc: 0.3491 - val_loss: 1.6990 - val_acc: 0.3794
# Epoch 94/100
# Epoch 00093: val_loss did not improve
# 30s - loss: 1.8182 - acc: 0.3433 - val_loss: 1.8721 - val_acc: 0.3204
# Epoch 95/100
# Epoch 00094: val_loss did not improve
# 30s - loss: 1.8150 - acc: 0.3428 - val_loss: 1.8626 - val_acc: 0.3238
# Epoch 96/100
# Epoch 00095: val_loss did not improve
# 30s - loss: 1.8417 - acc: 0.3351 - val_loss: 1.9686 - val_acc: 0.2880
# Epoch 97/100
# Epoch 00096: val_loss did not improve
# 30s - loss: 1.8236 - acc: 0.3435 - val_loss: 1.8698 - val_acc: 0.3038
# Epoch 98/100
# Epoch 00097: val_loss did not improve
# 30s - loss: 1.8287 - acc: 0.3386 - val_loss: 1.7334 - val_acc: 0.3748
# Epoch 99/100
# Epoch 00098: val_loss did not improve
# 30s - loss: 1.8359 - acc: 0.3337 - val_loss: 1.8302 - val_acc: 0.3446
# Epoch 100/100
# Epoch 00099: val_loss did not improve
# 30s - loss: 1.8419 - acc: 0.3332 - val_loss: 1.8161 - val_acc: 0.3360

# %% [markdown]
# ### 8. Load the Model with the Best Validation Accuracy

# %%
# load the weights that yielded the best validation accuracy
model.load_weights('model-cnn.weights.best.hdf5')

# %% [markdown]
# ### 9. Calculate Classification Accuracy on Test Set

# %%
# evaluate and print test accuracy
score = model.evaluate(x_test, y_test, verbose=0)
print('\n', 'Test accuracy:', score[1])
# Out:
#  Test accuracy: 0.5459

# %% [markdown]
# ### 10. Visualize Some Predictions
#
# This may give you some insight into why the network is misclassifying certain objects.

# %%
# get predictions on the test set
y_hat = model.predict(x_test)

# define text labels (source: https://www.cs.toronto.edu/~kriz/cifar.html)
cifar10_labels = ['airplane', 'automobile', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck']

# %%
# plot a random sample of test images, their predicted labels, and ground truth
fig = plt.figure(figsize=(20, 8))
for i, idx in enumerate(np.random.choice(x_test.shape[0], size=32, replace=False)):
    ax = fig.add_subplot(4, 8, i + 1, xticks=[], yticks=[])
    ax.imshow(np.squeeze(x_test[idx]))
    pred_idx = np.argmax(y_hat[idx])
    true_idx = np.argmax(y_test[idx])
    ax.set_title("{} ({})".format(cifar10_labels[pred_idx], cifar10_labels[true_idx]),
                 color=("green" if pred_idx == true_idx else "red"))
